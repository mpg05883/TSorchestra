# %% [markdown]
# # Configs

# %% [markdown]
# Import packages.

# %%
import pandas as pd
import yaml

from pathlib import Path

# %% [markdown]
# Read the GIFT-Eval datasets' metadata.

# %%
metadata_path = Path("../src/data/meta/metadata.csv")

df = pd.read_csv(metadata_path)

print(f"shape: {df.shape}")
df.head()
# Out:
# shape: (97, 10)
#               name   term freq     domain  _total_univariate_series  \
# 0  LOOP_SEATTLE/5T  short   5T  Transport                       323
# 1   LOOP_SEATTLE/D  short    D  Transport                       323
# 2   LOOP_SEATTLE/H  short    H  Transport                       323
# 3        M_DENSE/D  short    D  Transport                        30
# 4        M_DENSE/H  short    H  Transport                        30
#
#    target_dim  _min_series_length  sum_series_length  prediction_length  \
# 0           1              105120           33953760                 48
# 1           1                 365             117895                 30
# 2           1                8760            2829480                 48
# 3           1                 730              21900                 30
# 4           1               17520             525600                 48
#
#    windows
# 0       20
# 1        2
# 2       19
# 3        3
# 4       20

# %% [markdown]
# Count the max number of univariate series that belong to a single dataset across all domains.

# %%
domains = df['domain'].unique().tolist()

rows = []

for domain in domains:
    filtered_df = df[df['domain'] == domain]
    
    rows.append({
        "domain": domain,
        "num_datasets": len(filtered_df),
        "total_series": filtered_df["_total_univariate_series"].sum(),
        "max_series": filtered_df["_total_univariate_series"].max(),
    })

summary_df = pd.DataFrame(rows).sort_values(by="total_series", ascending=True).reset_index(drop=True)
display(summary_df)
# Out:
#          domain  num_datasets  total_series  max_series
# 0    Healthcare             5          1036         767
# 1     Transport            15          3005         323
# 2         Sales             4          3717        2674
# 3        Energy            32          4168         370
# 4  Web/CloudOps            20         14174        2500
# 5        Nature            15         33302       32072
# 6      Econ/Fin             6         99974       48000

# %% [markdown]
# Read the "all" data config.

# %%
config_path = Path("../conf/data/all.yaml")

with open(config_path, "r") as f:
    config = yaml.safe_load(f)
    
config_df = pd.DataFrame(config)

# Limit the DataFrame to the first 55 rows
limited_df = config_df.head(55)

# Count the rows where the 'term' column equals "short"
short_count = (limited_df['term'] == "short").sum()

print(f"Number of rows where 'term' equals 'short': {short_count}")

display(limited_df)
# Out:
# Number of rows where 'term' equals 'short': 55
#                              name   term
# 0                 LOOP_SEATTLE/5T  short
# 1                  LOOP_SEATTLE/D  short
# 2                  LOOP_SEATTLE/H  short
# 3                       M_DENSE/D  short
# 4                       M_DENSE/H  short
# 5                     SZ_TAXI/15T  short
# 6                       SZ_TAXI/H  short
# 7       bitbrains_fast_storage/5T  short
# 8        bitbrains_fast_storage/H  short
# 9                bitbrains_rnd/5T  short
# 10                bitbrains_rnd/H  short
# 11           bizitobs_application  short
# 12                bizitobs_l2c/5T  short
# 13                 bizitobs_l2c/H  short
# 14               bizitobs_service  short
# 15         car_parts_with_missing  short
# 16                   covid_deaths  short
# 17                electricity/15T  short
# 18                  electricity/D  short
# 19                  electricity/H  short
# 20                  electricity/W  short
# 21                       ett1/15T  short
# 22                         ett1/D  short
# 23                         ett1/H  short
# 24                         ett1/W  short
# 25                       ett2/15T  short
# 26                         ett2/D  short
# 27                         ett2/H  short
# 28                         ett2/W  short
# 29           hierarchical_sales/D  short
# 30           hierarchical_sales/W  short
# 31                       hospital  short
# 32               jena_weather/10T  short
# 33                 jena_weather/D  short
# 34                 jena_weather/H  short
# 35    kdd_cup_2018_with_missing/D  short
# 36    kdd_cup_2018_with_missing/H  short
# 37                       m4_daily  short
# 38                      m4_hourly  short
# 39                     m4_monthly  short
# 40                   m4_quarterly  short
# 41                      m4_weekly  short
# 42                      m4_yearly  short
# 43                     restaurant  short
# 44                   saugeenday/D  short
# 45                   saugeenday/M  short
# 46                   saugeenday/W  short
# 47                      solar/10T  short
# 48                        solar/D  short
# 49                        solar/H  short
# 50                        solar/W  short
# 51  temperature_rain_with_missing  short
# 52                    us_births/D  short
# 53                    us_births/M  short
# 54                    us_births/W  short
